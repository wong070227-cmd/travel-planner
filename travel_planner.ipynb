# %%
#itinerary builder in python
from datetime import datetime
def get_valid_date(prompt):
    while True:
        date_str = input(prompt)
        try:
            date_obj = datetime.strptime(date_str, "%Y-%m-%d")
            return date_obj
        except ValueError:
            print("Invalid date format! Please enter in YYYY-MM-DD format.")

def menu():
    while True:
        print("\n=== Itinerary Builder ===")
        print("1. Add Trip")
        print("2. Add Accommodation")
        print("3. Add Activity")
        print("4. View Itinerary")
        print("5. Edit Trip")
        print("6. Delete Trip")
        print("0. Exit")
        choice = input("Select an option: ")
        
        if choice == "1":
            add_trip()
        elif choice == "2":
            add_accommodation()
        elif choice == "3":
            add_activity()
        elif choice == "4":
            view_itinerary()
        elif choice == "5":
            edit_trip()
        elif choice == "6":
            delete_trip()
        elif choice == "0":
            print("Exiting Itinerary Builder. Goodbye!")
            break
        else:
            print("Invalid choice. Try again.\n")

# Add a new trip
def add_trip():
    trip_name = input("Enter trip name: ")
    destination = input("Enter destination: ")
    start_date = get_valid_date("Enter start date (YYYY-MM-DD): ")
    end_date = get_valid_date("Enter end date (YYYY-MM-DD): ")

    if end_date < start_date:
        print("End date cannot be before start date.")
        return

menu()
# Out:
# === Itinerary Builder ===
# 1. Add Trip
# 2. Add Accommodation
# 3. Add Activity
# 4. View Itinerary
# 5. Edit Trip
# 6. Delete Trip
# 0. Exit
# Select an option:  1
# Enter trip name:  summer vacation
# Enter destination:  bali
# Enter start date (YYYY-MM-DD):  2026-11-29
# Enter end date (YYYY-MM-DD):  2026-12-5
# === Itinerary Builder ===
# 1. Add Trip
# 2. Add Accommodation
# 3. Add Activity
# 4. View Itinerary
# 5. Edit Trip
# 6. Delete Trip
# 0. Exit
# Select an option:  1
# Enter trip name:
# Enter destination:
# Enter start date (YYYY-MM-DD):
# Invalid date format! Please enter in YYYY-MM-DD format.

# %%
# Packing List Generator

# %%
# Emergency Contact List
